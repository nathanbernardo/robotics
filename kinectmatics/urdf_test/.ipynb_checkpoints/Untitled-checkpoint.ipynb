# %%
import ikpy.chain
import numpy as np
import ikpy.utils.plot as plot_utils
import ikpy.urdf.utils as urdf_utils

# %%
my_chain = ikpy.chain.Chain.from_urdf_file("./chungus.URDF")

# %%
target_position = [ 1, 0.5, 1.5]

# %%
print("The angles of each joints are : ", my_chain.inverse_kinematics(target_position))
# Out:
# The angles of each joints are :  [-2.18246368e-15 -1.57079633e+00  1.24904833e+00 -5.45368392e-06
#   0.00000000e+00]

# %%
real_frame = my_chain.forward_kinematics(my_chain.inverse_kinematics(target_position))
print("Computed position vector : %s, original position vector : %s" % (real_frame[:3, 3], target_position))
# Out:
# Computed position vector : [0.81622792 0.5        0.94868325], original position vector : [1, 0.5, 1.5]

# %%
# %matplotlib inline
# %matplotlib widget
import matplotlib.pyplot as plt
fig, ax = plot_utils.init_3d_figure()
my_chain.plot(my_chain.inverse_kinematics(target_position), ax, target=target_position)
plt.xlim(-2, 2)
plt.ylim(-2, 2)
# Out:
# (-2.0, 2.0)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(urdf_utils.get_urdf_tree('./chungus.URDF', 'base_link'))
# Out:
# (<graphviz.graphs.Digraph object at 0x7b97f73a0e90>, URDF Link: base_link;
# )
